# %% [markdown]
# #### <b>Download the Dataset</b>
#
# - data path :
# https://github.com/LimHaY/2023_AI1_team9/releases/download/custom_dataset/custom_family_dataset.zip

# %%
# %%capture
# !wget https://github.com/LimHaY/2023_AI1_team9/releases/download/custom_dataset/custom_family_dataset.zip -O custom_family_dataset.zip
# !unzip custom_family_dataset.zip -d ./custom_family_dataset

# %% [markdown]
# #### <b>Load Libraries</b>

# %%
# 얼굴영역 인식 라이브러리 설치
# !pip install facenet_pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting facenet_pytorch
#   Downloading facenet_pytorch-2.5.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 73.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from facenet_pytorch) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from facenet_pytorch) (2.27.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from facenet_pytorch) (0.15.2+cu118)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from facenet_pytorch) (8.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->facenet_pytorch) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->facenet_pytorch) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->facenet_pytorch) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->facenet_pytorch) (3.4)
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.10/dist-packages (from torchvision->facenet_pytorch) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision->facenet_pytorch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision->facenet_pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision->facenet_pytorch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision->facenet_pytorch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision->facenet_pytorch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision->facenet_pytorch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision->facenet_pytorch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision->facenet_pytorch) (16.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1->torchvision->facenet_pytorch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1->torchvision->facenet_pytorch) (1.3.0)
# Installing collected packages: facenet_pytorch
# Successfully installed facenet_pytorch-2.5.3

# %%
import random
import os
import time
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torchvision

import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch.optim.lr_scheduler import ReduceLROnPlateau

from facenet_pytorch import InceptionResnetV1

# %%
"""
> [Function] Parse the metadata.
* family_list = ["F0001", "F0002", ...]
* family_to_person_map["F0001"] = ["D", "GM", "M"]
* person_to_image_map["F0001_D"] = [
    "F0001_AGE_D_18_a1.jpg",
    "F0001_AGE_D_18_a2.jpg",
    ...
]
"""
# metadata 를 parsing 하는 함수 
def parsing(metadata):
    family_set = set()
    family_to_person_map = dict()
    person_to_image_map = dict()
    # iterate all rows in the metadata file
    for idx, row in metadata.iterrows():
        family_id = row["family_id"]
        person_id = row["person_id"]
        key = family_id + "_" + person_id
        image_path = row["image_path"]
        if family_id not in family_set:
            family_set.add(family_id)
            family_to_person_map[family_id] = []
        if person_id not in family_to_person_map[family_id]:
            family_to_person_map[family_id].append(str(person_id))    
            person_to_image_map[key] = []
        person_to_image_map[key].append(image_path) # save all image paths
    family_list = list(family_set)
    return family_list, family_to_person_map, person_to_image_map

# %% [markdown]
# #### <b>Configuration</b>

# %%
batch_size = 64
lr = 0.001
log_step = 20
weights = [6, 5, 2]
weight_map = {
    'D': 0,
    'D2': 0,
    'D3': 0,
    'D4': 0,
    'S': 0,
    'S2': 0,
    'S3': 0,
    'S4': 0,
    'F': 1,
    'M': 1,
    'GF': 2,
    'GM': 2
}

# %% [markdown]
# #### <b>Load Datasets</b>
#
# * Training dataset
#   * (F0001 ~ F0727) folders have 22,427 images.
# * Validation dataset
#   * (F0728 ~ F0812) folders have 2,712 images.
# * Test dataset
#   * (F0813 ~ F0900) folders have 2,670 images.

# %%
# train data 반환하는 class : 비교할 이미지(img1,img2), label, 사전 학습된 weight 반환
class TrainDataset(Dataset):
    def __init__(self, meta_data, image_directory, transform=None):
        self.meta_data = meta_data
        self.image_directory = image_directory
        self.transform = transform

        # process the meta data
        family_list, family_to_person_map, person_to_image_map = parsing(meta_data)
        self.family_list = family_list
        self.family_to_person_map = family_to_person_map
        self.person_to_image_map = person_to_image_map

    def __len__(self):
        return len(self.meta_data) * 2
               
    def __getitem__(self, idx):
        # positive samples (family)
        if idx % 2 == 0:
            # choice a single family
            family_id = random.choice(self.family_list)
            # choice 2 different person in a single family
            p1, p2 = random.sample(self.family_to_person_map[family_id], 2) 
            key1 = family_id + "_" + p1
            key2 = family_id + "_" + p2
            label = 1
        # negative samples (not family)
        else:
            # choice 2 different familiy
            f1, f2 = random.sample(self.family_list, 2)
            # choice a person in each family
            p1 = random.choice(self.family_to_person_map[f1])
            p2 = random.choice(self.family_to_person_map[f2])
            key1 = f1 + "_" + p1
            key2 = f2 + "_" + p2
            label = 0

        path1 = random.choice(self.person_to_image_map[key1])
        path2 = random.choice(self.person_to_image_map[key2])

        img1 = Image.open(os.path.join(self.image_directory, path1))
        img2 = Image.open(os.path.join(self.image_directory, path2))

        g1 = path1.split('_')[2]
        g2 = path2.split('_')[2]
        weight = weights[abs(weight_map[g1] - weight_map[g2])]
        
        if self.transform:
            img1, img2 = self.transform(img1), self.transform(img2)
        
        return img1, img2, label, weight

# %%
# 평가 data 반환하는 class : 비교할 이미지(img1,img2), label, 사전 학습된 weight반환
class EvaluationDataset(Dataset):
    def __init__(self, image_directory, transform=None):
        self.positive_folder = os.path.join(image_directory, "positive")
        self.negative_folder = os.path.join(image_directory, "negative")
        self.positive_list = os.listdir(self.positive_folder)
        self.negative_list = os.listdir(self.negative_folder)
        self.transform = transform

    def __len__(self):
        return len(self.positive_list) + len(self.negative_list)

    def __getitem__(self, idx):
        # positive samples (family)
        if idx % 2 == 0:
            result_folder = os.path.join(self.positive_folder, self.positive_list[idx // 2])
            file1, file2 = os.listdir(result_folder)
            label = 1
        # negative samples (not family)
        else:
            result_folder = os.path.join(self.negative_folder, self.negative_list[idx // 2])
            file1, file2 = os.listdir(result_folder)
            label = 0

        img1 = Image.open(os.path.join(result_folder, file1))
        img2 = Image.open(os.path.join(result_folder, file2))

        g1 = file1.split('_')[2]
        g2 = file2.split('_')[2]
        weight = weights[abs(weight_map[g1] - weight_map[g2])]

        if self.transform:
            img1, img2 = self.transform(img1), self.transform(img2)

        return img1, img2, label, weight

# %%
# 데이터로더 정의

train_meta_data_path = "./custom_family_dataset/custom_train_dataset.csv"
train_meta_data = pd.read_csv(train_meta_data_path)
train_image_directory = "./custom_family_dataset/train_images"

val_image_directory = "./custom_family_dataset/fixed_val_dataset"
test_image_directory = "./custom_family_dataset/fixed_test_dataset"

train_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]) 
])

val_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]) 
])

test_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]) 
])

train_dataset = TrainDataset(train_meta_data, train_image_directory, train_transform)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = EvaluationDataset(val_image_directory, val_transform)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

test_dataset = EvaluationDataset(test_image_directory, test_transform)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# 데이터 샘플 확인

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 60
plt.rcParams.update({'font.size': 20})


def imshow(input):
    # torch.Tensor => numpy
    input = input.numpy().transpose((1, 2, 0))
    # undo image normalization
    mean = np.array([0.5, 0.5, 0.5])
    std = np.array([0.5, 0.5, 0.5])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    # display images
    plt.imshow(input)
    plt.show()


# load a batch of train image
iterator = iter(train_dataloader)

# visualize a batch of train image
img1, img2, label, weight = next(iterator)
out = torchvision.utils.make_grid(img1[:4])
imshow(out)
out = torchvision.utils.make_grid(img2[:4])
imshow(out)
print(label[:4]) # 1: family, 0: not family
# Out:
# tensor([1, 1, 0, 1])

# %% [markdown]
# #### <b>Define Models</b>
# - https://tyami.github.io/deep%20learning/Siamese-neural-networks/ 참조

# %%
class SiameseNet(nn.Module):
    def __init__(self):
        super().__init__()

        self.encoder = InceptionResnetV1(pretrained='vggface2')  #  vggface2 를 이용하여 얼굴영역 검출
        self.emb_dim = 512

        self.last = nn.Sequential(
            nn.Linear(4 * self.emb_dim, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Linear(256, 1)
        )
        
    def forward(self, input1, input2):
        emb1 = self.encoder(input1)
        emb2 = self.encoder(input2)
        
        x1 = torch.pow(emb1, 2) - torch.pow(emb2, 2)
        x2 = torch.pow(emb1 - emb2, 2)
        x3 = emb1 * emb2
        x4 = emb1 + emb2
        
        x = torch.cat((x1, x2, x3, x4), dim=1)
        x = self.last(x)

        return x

# %% [markdown]
# #### <b>Train a Model</b>

# %%
net = SiameseNet().cuda()
net = torch.nn.DataParallel(net)

criterion = nn.BCEWithLogitsLoss(reduction="none")
optimizer = torch.optim.SGD(net.parameters(), lr=lr)
scheduler = ReduceLROnPlateau(optimizer, patience=5)
sigmoid = nn.Sigmoid()
# Out:
#   0%|          | 0.00/107M [00:00<?, ?B/s]

# %%
def train():
    start_time = time.time()
    print(f'[Epoch: {epoch + 1} - Training]')
    net.train()
    total = 0
    running_loss = 0.0
    running_corrects = 0

    for i, batch in enumerate(train_dataloader):
        optimizer.zero_grad()
        
        img1, img2, label, weight = batch
        img1, img2, label, weight = img1.cuda(), img2.cuda(), label.float().view(-1, 1).cuda(), weight.float().view(-1, 1).cuda()

        output = net(img1, img2)
        preds = sigmoid(output) >= 0.5
        loss = criterion(output, label)
        loss = loss * weight
        loss = torch.mean(loss)

        loss.backward()
        optimizer.step()
        
        total += label.shape[0]
        running_loss += loss.item()
        running_corrects += torch.sum(preds == (label >= 0.5))
        
        if i % log_step == log_step - 1:
            print(f'[Batch: {i + 1}] running train loss: {running_loss / total}, running train accuracy: {running_corrects / total}')

    print(f'train loss: {running_loss / total}, accuracy: {running_corrects / total}')
    print("elapsed time:", time.time() - start_time)
    return running_loss / total, (running_corrects / total).item()


def validate():
    start_time = time.time()
    print(f'[Epoch: {epoch + 1} - Validation]')
    net.eval()
    total = 0
    running_loss = 0.0
    running_corrects = 0

    for i, batch in enumerate(val_dataloader):
        img1, img2, label, weight = batch
        img1, img2, label, weight = img1.cuda(), img2.cuda(), label.float().view(-1, 1).cuda(), weight.float().view(-1, 1).cuda()

        with torch.no_grad():
            output = net(img1, img2)
            preds = sigmoid(output) >= 0.5
            loss = criterion(output, label)
            loss = loss * weight
            loss = torch.mean(loss)

        total += label.shape[0]
        running_loss += loss.item()
        running_corrects += torch.sum(preds == (label >= 0.5))

        if (i == 0) or (i % log_step == log_step - 1):
            print(f'[Batch: {i + 1}] running val loss: {running_loss / total}, running val accuracy: {running_corrects / total}')

    print(f'val loss: {running_loss / total}, accuracy: {running_corrects / total}')
    print("elapsed time:", time.time() - start_time)
    return running_loss / total, (running_corrects / total).item()

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
## 런타임 연결 끊김 해제 
while True:pass

# %%
saved_path = "/content/gdrive/MyDrive/Colab Notebooks/AI1"  # 모델 저장할 경로
num_epochs = 20
best_val_acc = 0
best_epoch = 0

history = []
accuracy = []
for epoch in range(num_epochs):
    train_loss, train_acc = train()
    val_loss, val_acc = validate()
    history.append((train_loss, val_loss))
    accuracy.append((train_acc, val_acc))
    scheduler.step(val_loss)

    if val_acc > best_val_acc:
        print("[Info] best validation accuracy!")
        best_val_acc = val_acc
        best_epoch = epoch
        torch.save(net.state_dict(), f'{saved_path}/best_checkpoint_epoch_{epoch + 1}.pth')
    torch.save(net.state_dict(), f'{saved_path}/checkpoint_epoch_{epoch + 1}.pth')

torch.save(net.state_dict(), f'{saved_path}/last_checkpoint_epoch_{num_epochs}.pth')
# Out:
# [Epoch: 1 - Training]
# [Batch: 20] running train loss: 0.054710103571414946, running train accuracy: 0.48750001192092896
# [Batch: 40] running train loss: 0.05492747770622373, running train accuracy: 0.49140626192092896
# [Batch: 60] running train loss: 0.05490036600579818, running train accuracy: 0.4997396171092987
# [Batch: 80] running train loss: 0.05503848637454212, running train accuracy: 0.4957031309604645
# [Batch: 100] running train loss: 0.054775905422866346, running train accuracy: 0.5059375166893005
# [Batch: 120] running train loss: 0.05481659152234594, running train accuracy: 0.5071614980697632
# [Batch: 140] running train loss: 0.05476273452597005, running train accuracy: 0.5108258724212646
# [Batch: 160] running train loss: 0.05466024063061923, running train accuracy: 0.51171875
# [Batch: 180] running train loss: 0.05462860870692465, running train accuracy: 0.5142361521720886
# [Batch: 200] running train loss: 0.054471604712307456, running train accuracy: 0.5163280963897705
# [Batch: 220] running train loss: 0.05440627429634333, running train accuracy: 0.5194602012634277
# [Batch: 240] running train loss: 0.05442117884134253, running train accuracy: 0.5200521349906921
# [Batch: 260] running train loss: 0.0543947214833819, running train accuracy: 0.5213942527770996
# [Batch: 280] running train loss: 0.054301487428269214, running train accuracy: 0.5238281488418579
# [Batch: 300] running train loss: 0.054314703084528446, running train accuracy: 0.5241667032241821
# [Batch: 320] running train loss: 0.054295737703796476, running train accuracy: 0.525390625
# [Batch: 340] running train loss: 0.05422868931337314, running train accuracy: 0.5272518396377563
# [Batch: 360] running train loss: 0.05421278319425053, running train accuracy: 0.5284722447395325
# [Batch: 380] running train loss: 0.05422325551901993, running train accuracy: 0.5294819474220276
# [Batch: 400] running train loss: 0.05421849731355906, running train accuracy: 0.5298437476158142
# [Batch: 420] running train loss: 0.05418296129930587, running train accuracy: 0.5319940447807312
# [Batch: 440] running train loss: 0.05421277234669436, running train accuracy: 0.5324928760528564
# [Batch: 460] running train loss: 0.05416903991414153, running train accuracy: 0.533186137676239
# [Batch: 480] running train loss: 0.05412975400686264, running train accuracy: 0.5339192748069763
# [Batch: 500] running train loss: 0.054097827591001985, running train accuracy: 0.534375011920929
# [Batch: 520] running train loss: 0.05409094350269208, running train accuracy: 0.5346454381942749
# [Batch: 540] running train loss: 0.054067842172527754, running train accuracy: 0.5352141261100769
# [Batch: 560] running train loss: 0.054032004651214396, running train accuracy: 0.5367745757102966
# [Batch: 580] running train loss: 0.05401859100394208, running train accuracy: 0.5376885533332825
# [Batch: 600] running train loss: 0.05397428911800186, running train accuracy: 0.5391927361488342
# [Batch: 620] running train loss: 0.053953937188752236, running train accuracy: 0.5396169424057007
# [Batch: 640] running train loss: 0.053911441762465984, running train accuracy: 0.541186511516571
# [Batch: 660] running train loss: 0.0538699816009312, running train accuracy: 0.5418323874473572
# [Batch: 680] running train loss: 0.053836117098655774, running train accuracy: 0.5423253774642944
# [Batch: 700] running train loss: 0.05378711173044784, running train accuracy: 0.5434598326683044
# train loss: 0.05379744172335447, accuracy: 0.5435858964920044
# elapsed time: 1254.2629475593567
# [Epoch: 1 - Validation]
# [Batch: 1] running val loss: 0.05404748022556305, running val accuracy: 0.640625
# [Batch: 20] running val loss: 0.05686053819954395, running val accuracy: 0.522656261920929
# [Batch: 40] running val loss: 0.057074067648500204, running val accuracy: 0.5132812857627869
# [Batch: 60] running val loss: 0.05689844476679961, running val accuracy: 0.5200521349906921
# [Batch: 80] running val loss: 0.05706308544613421, running val accuracy: 0.51953125
# [Batch: 100] running val loss: 0.05715651012957096, running val accuracy: 0.5207812190055847
# [Batch: 120] running val loss: 0.057162533265848955, running val accuracy: 0.5256510972976685
# [Batch: 140] running val loss: 0.05703710221818515, running val accuracy: 0.526562511920929
# val loss: 0.05724055037498474, accuracy: 0.5257999897003174
# elapsed time: 123.223140001297
# [Info] best validation accuracy!
# [Epoch: 2 - Training]
# [Batch: 20] running train loss: 0.054124906100332736, running train accuracy: 0.573437511920929
# [Batch: 40] running train loss: 0.053190069273114204, running train accuracy: 0.5765625238418579
# [Batch: 60] running train loss: 0.05310965639849504, running train accuracy: 0.5750000476837158
# [Batch: 80] running train loss: 0.05292323878966272, running train accuracy: 0.5767578482627869
# [Batch: 100] running train loss: 0.05301049154251814, running train accuracy: 0.5753124952316284
# [Batch: 120] running train loss: 0.052878177352249624, running train accuracy: 0.5824218988418579
# [Batch: 140] running train loss: 0.05289586090615817, running train accuracy: 0.5814732313156128
# [Batch: 160] running train loss: 0.052894545975141226, running train accuracy: 0.5821289420127869
# [Batch: 180] running train loss: 0.052960242620772785, running train accuracy: 0.5789930820465088
# [Batch: 200] running train loss: 0.052992949914187196, running train accuracy: 0.5771874785423279
# [Batch: 220] running train loss: 0.05295742135494948, running train accuracy: 0.5766335129737854
# [Batch: 240] running train loss: 0.052898871696864566, running train accuracy: 0.5775390863418579
# [Batch: 260] running train loss: 0.052822653805980314, running train accuracy: 0.5790865421295166
# [Batch: 280] running train loss: 0.052789249923080206, running train accuracy: 0.5792410969734192
# [Batch: 300] running train loss: 0.052809532843530176, running train accuracy: 0.578697919845581
# [Batch: 320] running train loss: 0.052730971027631315, running train accuracy: 0.5809570550918579
# [Batch: 340] running train loss: 0.05266122473951648, running train accuracy: 0.5822610259056091
# [Batch: 360] running train loss: 0.052649081798477305, running train accuracy: 0.5822482705116272
# [Batch: 380] running train loss: 0.05263117553764268, running train accuracy: 0.5824835896492004
# [Batch: 400] running train loss: 0.05262297138571739, running train accuracy: 0.5830078125
# [Batch: 420] running train loss: 0.052635050015080544, running train accuracy: 0.5831101536750793
# [Batch: 440] running train loss: 0.05260525018992749, running train accuracy: 0.5833096504211426
# [Batch: 460] running train loss: 0.05258099644080452, running train accuracy: 0.584510862827301
# [Batch: 480] running train loss: 0.0525868597595642, running train accuracy: 0.5842773914337158
# [Batch: 500] running train loss: 0.05255855031311512, running train accuracy: 0.585281252861023
# [Batch: 520] running train loss: 0.05251138989025583, running train accuracy: 0.5858173370361328
# [Batch: 540] running train loss: 0.05245503341710126, running train accuracy: 0.5870081186294556
# [Batch: 560] running train loss: 0.052398370765149596, running train accuracy: 0.587276816368103
# [Batch: 580] running train loss: 0.052345688891564976, running train accuracy: 0.5879849195480347
# [Batch: 600] running train loss: 0.05228969679524501, running train accuracy: 0.5888802409172058
# [Batch: 620] running train loss: 0.05229017857101656, running train accuracy: 0.5897429585456848
# [Batch: 640] running train loss: 0.0522609437641222, running train accuracy: 0.5902343988418579
# [Batch: 660] running train loss: 0.05225306080484932, running train accuracy: 0.5909327268600464
# [Batch: 680] running train loss: 0.052239423387629144, running train accuracy: 0.5911075472831726
# [Batch: 700] running train loss: 0.052204977683722974, running train accuracy: 0.5921874642372131
# train loss: 0.05221127989076657, accuracy: 0.5922325849533081
# elapsed time: 1264.850965499878
# [Epoch: 2 - Validation]
# [Batch: 1] running val loss: 0.057143766433000565, running val accuracy: 0.53125
# [Batch: 20] running val loss: 0.056758763641119, running val accuracy: 0.546093761920929
# [Batch: 40] running val loss: 0.056909171678125856, running val accuracy: 0.5406250357627869
# [Batch: 60] running val loss: 0.05657464688022931, running val accuracy: 0.5528646111488342
# [Batch: 80] running val loss: 0.05695542679168284, running val accuracy: 0.5472656488418579
# [Batch: 100] running val loss: 0.05718040719628334, running val accuracy: 0.5420312285423279
# [Batch: 120] running val loss: 0.057169837815066175, running val accuracy: 0.544140636920929
# [Batch: 140] running val loss: 0.05708338099398783, running val accuracy: 0.5445312261581421
# val loss: 0.05726442120075226, accuracy: 0.5446999669075012
# elapsed time: 124.37176752090454
# [Info] best validation accuracy!
# [Epoch: 3 - Training]
# [Batch: 20] running train loss: 0.050773034989833835, running train accuracy: 0.6031250357627869
# [Batch: 40] running train loss: 0.0510241094045341, running train accuracy: 0.5960937738418579
# [Batch: 60] running train loss: 0.0508652264252305, running train accuracy: 0.6091145873069763
# [Batch: 80] running train loss: 0.05106628299690783, running train accuracy: 0.608593761920929
# [Batch: 100] running train loss: 0.05087344437837601, running train accuracy: 0.6118749976158142
# [Batch: 120] running train loss: 0.05090363066022595, running train accuracy: 0.6145833730697632
# [Batch: 140] running train loss: 0.05091208102447646, running train accuracy: 0.614062488079071
# [Batch: 160] running train loss: 0.05089393106754869, running train accuracy: 0.612988293170929
# [Batch: 180] running train loss: 0.05089721091919475, running train accuracy: 0.6151909828186035
# [Batch: 200] running train loss: 0.050887731481343505, running train accuracy: 0.6155468821525574
# [Batch: 220] running train loss: 0.05091343975879929, running train accuracy: 0.6161931753158569
# [Batch: 240] running train loss: 0.05089846677146852, running train accuracy: 0.6182942986488342
# [Batch: 260] running train loss: 0.050862868244831376, running train accuracy: 0.6176682710647583
# [Batch: 280] running train loss: 0.05081532576254436, running train accuracy: 0.6179129481315613
# [Batch: 300] running train loss: 0.05078069088359674, running train accuracy: 0.6184896230697632
# [Batch: 320] running train loss: 0.050794619438238445, running train accuracy: 0.617919921875
# [Batch: 340] running train loss: 0.050785008598776424, running train accuracy: 0.618244469165802
# [Batch: 360] running train loss: 0.0507915113431712, running train accuracy: 0.6182292103767395
# [Batch: 380] running train loss: 0.050840181161306404, running train accuracy: 0.6175987124443054
# [Batch: 400] running train loss: 0.05081511890515685, running train accuracy: 0.6178125143051147
# [Batch: 420] running train loss: 0.05077369135050547, running train accuracy: 0.6190104484558105
# [Batch: 440] running train loss: 0.05076307706873525, running train accuracy: 0.6201349496841431
# [Batch: 460] running train loss: 0.05075601345818976, running train accuracy: 0.6200746893882751
# [Batch: 480] running train loss: 0.05077840148005634, running train accuracy: 0.620312511920929
# [Batch: 500] running train loss: 0.05075032288581133, running train accuracy: 0.6212812662124634
# [Batch: 520] running train loss: 0.050754765499956334, running train accuracy: 0.6220252513885498
# [Batch: 540] running train loss: 0.05069963360136306, running train accuracy: 0.6230323910713196
# [Batch: 560] running train loss: 0.050723865222451946, running train accuracy: 0.623046875
# [Batch: 580] running train loss: 0.05065647281449417, running train accuracy: 0.6237338185310364
# [Batch: 600] running train loss: 0.05064352917174498, running train accuracy: 0.6240364909172058
# [Batch: 620] running train loss: 0.05059005723845574, running train accuracy: 0.6248739957809448
# [Batch: 640] running train loss: 0.05058455025427975, running train accuracy: 0.625537097454071
# [Batch: 660] running train loss: 0.050522428660681754, running train accuracy: 0.6265388131141663
# [Batch: 680] running train loss: 0.05046073350617114, running train accuracy: 0.6269761323928833
# [Batch: 700] running train loss: 0.05045347977429628, running train accuracy: 0.6273883581161499
# train loss: 0.050464383224937716, accuracy: 0.6273910999298096
# elapsed time: 1267.0507593154907
# [Epoch: 3 - Validation]
# [Batch: 1] running val loss: 0.0546480268239975, running val accuracy: 0.609375
# [Batch: 20] running val loss: 0.057177058234810826, running val accuracy: 0.5390625
# [Batch: 40] running val loss: 0.057341127377003434, running val accuracy: 0.5328125357627869
# [Batch: 60] running val loss: 0.057117475134630995, running val accuracy: 0.5424479246139526
# [Batch: 80] running val loss: 0.05761677389964461, running val accuracy: 0.5367187857627869
# [Batch: 100] running val loss: 0.05789962682873011, running val accuracy: 0.5349999666213989
# [Batch: 120] running val loss: 0.0579582456809779, running val accuracy: 0.5361979603767395
# [Batch: 140] running val loss: 0.05790990913020713, running val accuracy: 0.5358259081840515
# val loss: 0.05808495144844055, accuracy: 0.5363999605178833
# elapsed time: 124.78257727622986
# [Epoch: 4 - Training]
# [Batch: 20] running train loss: 0.04882586244493723, running train accuracy: 0.655468761920929
# [Batch: 40] running train loss: 0.04905087826773524, running train accuracy: 0.650390625
# [Batch: 60] running train loss: 0.048909472798307735, running train accuracy: 0.6520833969116211
# [Batch: 80] running train loss: 0.0487594467587769, running train accuracy: 0.650390625
# [Batch: 100] running train loss: 0.04879599306732416, running train accuracy: 0.651562511920929
# [Batch: 120] running train loss: 0.04873436295116941, running train accuracy: 0.6520833969116211
# [Batch: 140] running train loss: 0.04887784072863204, running train accuracy: 0.6491071581840515
# [Batch: 160] running train loss: 0.04873004551045597, running train accuracy: 0.6498047113418579
# [Batch: 180] running train loss: 0.04858569951934947, running train accuracy: 0.6508680582046509
# [Batch: 200] running train loss: 0.04857889119535685, running train accuracy: 0.6521093845367432
# [Batch: 220] running train loss: 0.048580558327111334, running train accuracy: 0.6517045497894287
# [Batch: 240] running train loss: 0.04864463678871592, running train accuracy: 0.6516927480697632
# [Batch: 260] running train loss: 0.048609118722379205, running train accuracy: 0.6508413553237915
# [Batch: 280] running train loss: 0.048611854988017254, running train accuracy: 0.651729941368103
# [Batch: 300] running train loss: 0.04864880950500568, running train accuracy: 0.6502604484558105
# [Batch: 320] running train loss: 0.04865161054767668, running train accuracy: 0.6490722894668579
# [Batch: 340] running train loss: 0.04869315554113949, running train accuracy: 0.6493566036224365
# [Batch: 360] running train loss: 0.04870403330359194, running train accuracy: 0.6489149332046509
# [Batch: 380] running train loss: 0.04867126249561184, running train accuracy: 0.6495888233184814
# [Batch: 400] running train loss: 0.048661940228194, running train accuracy: 0.650195300579071
# [Batch: 420] running train loss: 0.048637652938209826, running train accuracy: 0.649776816368103
# [Batch: 440] running train loss: 0.04860097785395655, running train accuracy: 0.6498579382896423
# [Batch: 460] running train loss: 0.048546921299851456, running train accuracy: 0.6504075527191162
# [Batch: 480] running train loss: 0.04854610543698072, running train accuracy: 0.6505534052848816
# [Batch: 500] running train loss: 0.048525878511369226, running train accuracy: 0.6504687666893005
# [Batch: 520] running train loss: 0.04846613918646024, running train accuracy: 0.6516826748847961
# [Batch: 540] running train loss: 0.048391681316274186, running train accuracy: 0.653211772441864
# [Batch: 560] running train loss: 0.04834199074123587, running train accuracy: 0.6533482074737549
# [Batch: 580] running train loss: 0.04833233122039458, running train accuracy: 0.6541756391525269
# [Batch: 600] running train loss: 0.04829327259833614, running train accuracy: 0.6551823019981384
# [Batch: 620] running train loss: 0.048246149105891104, running train accuracy: 0.6560987830162048
# [Batch: 640] running train loss: 0.048187632934423165, running train accuracy: 0.6572510004043579
# [Batch: 660] running train loss: 0.04817194105549292, running train accuracy: 0.6575993895530701
# [Batch: 680] running train loss: 0.0481395822182736, running train accuracy: 0.6581571698188782
# [Batch: 700] running train loss: 0.04810355190187693, running train accuracy: 0.658973217010498
# train loss: 0.04811795788931348, accuracy: 0.658893346786499
# elapsed time: 1261.4839396476746
# [Epoch: 4 - Validation]
# [Batch: 1] running val loss: 0.05055191367864609, running val accuracy: 0.625
# [Batch: 20] running val loss: 0.05681355353444815, running val accuracy: 0.578125
# [Batch: 40] running val loss: 0.05737844165414572, running val accuracy: 0.5648437738418579
# [Batch: 60] running val loss: 0.0573736596852541, running val accuracy: 0.5619791746139526
# [Batch: 80] running val loss: 0.058182945428416136, running val accuracy: 0.5546875
# [Batch: 100] running val loss: 0.05848117046058178, running val accuracy: 0.5518749952316284
# [Batch: 120] running val loss: 0.058525986534853774, running val accuracy: 0.552734375
# [Batch: 140] running val loss: 0.05848339301134859, running val accuracy: 0.5523437261581421
# val loss: 0.05858726019859314, accuracy: 0.552899956703186
# elapsed time: 123.7802484035492
# [Info] best validation accuracy!
# [Epoch: 5 - Training]
# [Batch: 20] running train loss: 0.04540441669523716, running train accuracy: 0.6851562857627869
# [Batch: 40] running train loss: 0.04648262895643711, running train accuracy: 0.674609363079071
# [Batch: 60] running train loss: 0.046937091772754985, running train accuracy: 0.671093761920929
# [Batch: 80] running train loss: 0.04713565167039633, running train accuracy: 0.6669921875
# [Batch: 100] running train loss: 0.04697126541286707, running train accuracy: 0.6693750023841858
# [Batch: 120] running train loss: 0.04688609947140018, running train accuracy: 0.6727864742279053
# [Batch: 140] running train loss: 0.0468754504142063, running train accuracy: 0.6734374761581421
# [Batch: 160] running train loss: 0.04672310431487858, running train accuracy: 0.674511730670929
# [Batch: 180] running train loss: 0.04672267370753818, running train accuracy: 0.6736979484558105
# [Batch: 200] running train loss: 0.046708441600203515, running train accuracy: 0.6746875047683716
# [Batch: 220] running train loss: 0.046677475845949216, running train accuracy: 0.67578125
# [Batch: 240] running train loss: 0.04662053842718403, running train accuracy: 0.6764974594116211
# [Batch: 260] running train loss: 0.04662294693004627, running train accuracy: 0.6771634817123413
# [Batch: 280] running train loss: 0.04660536581650376, running train accuracy: 0.6763392686843872
# [Batch: 300] running train loss: 0.04659631408751011, running train accuracy: 0.6767187714576721
# [Batch: 320] running train loss: 0.046580570307560264, running train accuracy: 0.677001953125
# [Batch: 340] running train loss: 0.046534827242002766, running train accuracy: 0.6769301891326904
# [Batch: 360] running train loss: 0.04643394126453333, running train accuracy: 0.6764323115348816
# [Batch: 380] running train loss: 0.04641442838075914, running train accuracy: 0.6772615313529968
# [Batch: 400] running train loss: 0.04641671466641128, running train accuracy: 0.6774218678474426
# [Batch: 420] running train loss: 0.04633264660480477, running train accuracy: 0.6778646111488342
# [Batch: 440] running train loss: 0.046333069032566114, running train accuracy: 0.6774147748947144
# [Batch: 460] running train loss: 0.046264332055073715, running train accuracy: 0.6780230402946472
# [Batch: 480] running train loss: 0.04622377255000174, running train accuracy: 0.678417980670929
# [Batch: 500] running train loss: 0.04615474204719067, running train accuracy: 0.6792187690734863
# [Batch: 520] running train loss: 0.04609690557162349, running train accuracy: 0.6797776222229004
# [Batch: 540] running train loss: 0.046076704954935446, running train accuracy: 0.6807581186294556
# [Batch: 560] running train loss: 0.04605612617119082, running train accuracy: 0.6807477474212646
# [Batch: 580] running train loss: 0.04602769552890597, running train accuracy: 0.6817349195480347
# [Batch: 600] running train loss: 0.0460243693801264, running train accuracy: 0.6818490028381348
# [Batch: 620] running train loss: 0.045942495727250655, running train accuracy: 0.6825352907180786
# [Batch: 640] running train loss: 0.04587874363060109, running train accuracy: 0.683032214641571
# [Batch: 660] running train loss: 0.04579125853311835, running train accuracy: 0.6840909123420715
# [Batch: 680] running train loss: 0.045748597219148104, running train accuracy: 0.6848115921020508
# [Batch: 700] running train loss: 0.04573451818632228, running train accuracy: 0.6850446462631226
# train loss: 0.0457510566958062, accuracy: 0.6849779486656189
# elapsed time: 1263.620287656784
# [Epoch: 5 - Validation]
# [Batch: 1] running val loss: 0.054214008152484894, running val accuracy: 0.578125
# [Batch: 20] running val loss: 0.05575089231133461, running val accuracy: 0.59765625
# [Batch: 40] running val loss: 0.05581603851169348, running val accuracy: 0.588671863079071
# [Batch: 60] running val loss: 0.055958490322033566, running val accuracy: 0.5888020992279053
# [Batch: 80] running val loss: 0.05660114572383464, running val accuracy: 0.5816406607627869
# [Batch: 100] running val loss: 0.05676189079880714, running val accuracy: 0.5785937309265137
# [Batch: 120] running val loss: 0.05690612957502405, running val accuracy: 0.5774739980697632
# [Batch: 140] running val loss: 0.05700556002557278, running val accuracy: 0.5747767686843872
# val loss: 0.056905125212669376, accuracy: 0.5782999992370605
# elapsed time: 124.77383065223694
# [Info] best validation accuracy!
# [Epoch: 6 - Training]
# [Batch: 20] running train loss: 0.04428091365844011, running train accuracy: 0.696093738079071
# [Batch: 40] running train loss: 0.04372061360627413, running train accuracy: 0.710156261920929
# [Batch: 60] running train loss: 0.04403763593484958, running train accuracy: 0.7057291865348816
# [Batch: 80] running train loss: 0.043947811052203176, running train accuracy: 0.7044922113418579
# [Batch: 100] running train loss: 0.0436611470580101, running train accuracy: 0.7079687118530273
# [Batch: 120] running train loss: 0.04387483224272728, running train accuracy: 0.7057291865348816
# [Batch: 140] running train loss: 0.04381862123097692, running train accuracy: 0.704464316368103
# [Batch: 160] running train loss: 0.04392661741003394, running train accuracy: 0.703320324420929
# [Batch: 180] running train loss: 0.043947437633242874, running train accuracy: 0.703906238079071
# [Batch: 200] running train loss: 0.043932242542505266, running train accuracy: 0.7049218416213989
# [Batch: 220] running train loss: 0.04402749900790778, running train accuracy: 0.7038351893424988
# [Batch: 240] running train loss: 0.04394005186234911, running train accuracy: 0.7060547471046448
# [Batch: 260] running train loss: 0.043884161243645047, running train accuracy: 0.7066105604171753
# [Batch: 280] running train loss: 0.04375490618071386, running train accuracy: 0.7074218988418579
# [Batch: 300] running train loss: 0.04372276376932859, running train accuracy: 0.70703125
# [Batch: 320] running train loss: 0.04359511840157211, running train accuracy: 0.707324206829071
# [Batch: 340] running train loss: 0.04351029130904113, running train accuracy: 0.7078584432601929
# [Batch: 360] running train loss: 0.0433798828576174, running train accuracy: 0.7090712189674377
# [Batch: 380] running train loss: 0.04332104599789569, running train accuracy: 0.710156261920929
# [Batch: 400] running train loss: 0.043261001361534, running train accuracy: 0.7103124856948853
# [Batch: 420] running train loss: 0.04324332200700329, running train accuracy: 0.7109375
# [Batch: 440] running train loss: 0.04321871529417959, running train accuracy: 0.7102982997894287
# [Batch: 460] running train loss: 0.043203344479527166, running train accuracy: 0.7106996774673462
# [Batch: 480] running train loss: 0.04322480043241133, running train accuracy: 0.7100260853767395
# [Batch: 500] running train loss: 0.04323301719129086, running train accuracy: 0.7098125219345093
# [Batch: 520] running train loss: 0.04325633526851352, running train accuracy: 0.710036039352417
# [Batch: 540] running train loss: 0.043189896960501316, running train accuracy: 0.7109953761100769
# [Batch: 560] running train loss: 0.04314284209561135, running train accuracy: 0.711718738079071
# [Batch: 580] running train loss: 0.04311257325241278, running train accuracy: 0.7120689749717712
# [Batch: 600] running train loss: 0.043135185508678356, running train accuracy: 0.7117708325386047
# [Batch: 620] running train loss: 0.04308332276921118, running train accuracy: 0.7123487591743469
# [Batch: 640] running train loss: 0.043078398588113485, running train accuracy: 0.712573230266571
# [Batch: 660] running train loss: 0.043043194152414796, running train accuracy: 0.713304877281189
# [Batch: 680] running train loss: 0.04302751244977117, running train accuracy: 0.714062511920929
# [Batch: 700] running train loss: 0.04297292780663286, running train accuracy: 0.714866042137146
# train loss: 0.042987412948606696, accuracy: 0.7147857546806335
# elapsed time: 1271.1791591644287
# [Epoch: 6 - Validation]
# [Batch: 1] running val loss: 0.05567506328225136, running val accuracy: 0.59375
# [Batch: 20] running val loss: 0.06319888513535261, running val accuracy: 0.5804687738418579
# [Batch: 40] running val loss: 0.06277146637439728, running val accuracy: 0.575390636920929
# [Batch: 60] running val loss: 0.06295643659929434, running val accuracy: 0.573437511920929
# [Batch: 80] running val loss: 0.06357941864989698, running val accuracy: 0.5679687857627869
# [Batch: 100] running val loss: 0.06364928372204304, running val accuracy: 0.5654687285423279
# [Batch: 120] running val loss: 0.0639817896609505, running val accuracy: 0.5634114742279053
# [Batch: 140] running val loss: 0.06412774720894439, running val accuracy: 0.5618303418159485
# val loss: 0.06426430311203003, accuracy: 0.5611000061035156
# elapsed time: 124.61493253707886
# [Epoch: 7 - Training]
# [Batch: 20] running train loss: 0.04159029927104711, running train accuracy: 0.729687511920929
# [Batch: 40] running train loss: 0.04219118105247617, running train accuracy: 0.721875011920929
# [Batch: 60] running train loss: 0.041887107864022256, running train accuracy: 0.7278646230697632
# [Batch: 80] running train loss: 0.04194222316145897, running train accuracy: 0.721484363079071
# [Batch: 100] running train loss: 0.04156798705458641, running train accuracy: 0.7287499904632568
# [Batch: 120] running train loss: 0.04168340874214967, running train accuracy: 0.727734386920929
# [Batch: 140] running train loss: 0.04162657570892147, running train accuracy: 0.7293526530265808
# [Batch: 160] running train loss: 0.041456378751900044, running train accuracy: 0.7300781607627869
# [Batch: 180] running train loss: 0.04137481230621536, running train accuracy: 0.7310764193534851
# [Batch: 200] running train loss: 0.04150226133875549, running train accuracy: 0.7302343845367432
# [Batch: 220] running train loss: 0.041543389238755814, running train accuracy: 0.7316051125526428
# [Batch: 240] running train loss: 0.041570426484880345, running train accuracy: 0.7302083969116211
# [Batch: 260] running train loss: 0.0414664178298643, running train accuracy: 0.7313100695610046
# [Batch: 280] running train loss: 0.04135702004257057, running train accuracy: 0.7319196462631226
# [Batch: 300] running train loss: 0.04120083788409829, running train accuracy: 0.7328646183013916
# [Batch: 320] running train loss: 0.041276222275337206, running train accuracy: 0.731884777545929
# [Batch: 340] running train loss: 0.041102375396910834, running train accuracy: 0.7335018515586853
# [Batch: 360] running train loss: 0.04112134416484171, running train accuracy: 0.733203113079071
# [Batch: 380] running train loss: 0.04105557242506429, running train accuracy: 0.7338404655456543
# [Batch: 400] running train loss: 0.041031623473390934, running train accuracy: 0.7337499856948853
# [Batch: 420] running train loss: 0.04104305384237142, running train accuracy: 0.733593761920929
# [Batch: 440] running train loss: 0.04106622709130699, running train accuracy: 0.7334161996841431
# [Batch: 460] running train loss: 0.04099710203059342, running train accuracy: 0.733797550201416
# [Batch: 480] running train loss: 0.040938941001271205, running train accuracy: 0.7350260615348816
# [Batch: 500] running train loss: 0.04094053010642529, running train accuracy: 0.7350313067436218
# [Batch: 520] running train loss: 0.0408919336560827, running train accuracy: 0.735546886920929
# [Batch: 540] running train loss: 0.04084228758044817, running train accuracy: 0.7354166507720947
# [Batch: 560] running train loss: 0.04075255987034845, running train accuracy: 0.7359933257102966
# [Batch: 580] running train loss: 0.040763750026837506, running train accuracy: 0.7353717684745789
# [Batch: 600] running train loss: 0.04071658926395078, running train accuracy: 0.7359635829925537
# [Batch: 620] running train loss: 0.04065891761753348, running train accuracy: 0.736617922782898
# [Batch: 640] running train loss: 0.04062839884136338, running train accuracy: 0.7370361685752869
# [Batch: 660] running train loss: 0.040607444806532424, running train accuracy: 0.7372869253158569
# [Batch: 680] running train loss: 0.04056980200659703, running train accuracy: 0.7374540567398071
# [Batch: 700] running train loss: 0.04054950218115534, running train accuracy: 0.7373214364051819
# train loss: 0.040558901670630025, accuracy: 0.7373032569885254
# elapsed time: 1268.8964195251465
# [Epoch: 7 - Validation]
# [Batch: 1] running val loss: 0.05315874516963959, running val accuracy: 0.609375
# [Batch: 20] running val loss: 0.05959283541887998, running val accuracy: 0.592968761920929
# [Batch: 40] running val loss: 0.059962167590856555, running val accuracy: 0.583203136920929
# [Batch: 60] running val loss: 0.060231358061234155, running val accuracy: 0.5822917222976685
# [Batch: 80] running val loss: 0.060256319912150504, running val accuracy: 0.5859375
# [Batch: 100] running val loss: 0.060191089026629924, running val accuracy: 0.586718738079071
# [Batch: 120] running val loss: 0.060569412323335806, running val accuracy: 0.5842448472976685
# [Batch: 140] running val loss: 0.06064461123730455, running val accuracy: 0.5823660492897034
# val loss: 0.06076696760654449, accuracy: 0.5817999839782715
# elapsed time: 123.83257150650024
# [Info] best validation accuracy!
# [Epoch: 8 - Training]
# [Batch: 20] running train loss: 0.04034042321145535, running train accuracy: 0.7421875
# [Batch: 40] running train loss: 0.039936013612896205, running train accuracy: 0.743359386920929
# [Batch: 60] running train loss: 0.03962436507766445, running train accuracy: 0.7486979365348816
# [Batch: 80] running train loss: 0.03923443288076669, running train accuracy: 0.750781238079071
# [Batch: 100] running train loss: 0.039296364318579434, running train accuracy: 0.7512499690055847
# [Batch: 120] running train loss: 0.03929194142110646, running train accuracy: 0.7501302361488342
# [Batch: 140] running train loss: 0.039653478389871974, running train accuracy: 0.7463169693946838
# [Batch: 160] running train loss: 0.03978166080778465, running train accuracy: 0.7450195550918579
# [Batch: 180] running train loss: 0.03968787059808771, running train accuracy: 0.7457465529441833
# [Batch: 200] running train loss: 0.03950916824862361, running train accuracy: 0.7473437190055847
# [Batch: 220] running train loss: 0.039537612382661215, running train accuracy: 0.74609375
# [Batch: 240] running train loss: 0.0395361234433949, running train accuracy: 0.7466146349906921
# [Batch: 260] running train loss: 0.03948096253264409, running train accuracy: 0.7466946840286255
# [Batch: 280] running train loss: 0.03937717277024474, running train accuracy: 0.7472098469734192
# [Batch: 300] running train loss: 0.039269776083528996, running train accuracy: 0.7479166984558105
# [Batch: 320] running train loss: 0.03914417430059984, running train accuracy: 0.748828113079071
# [Batch: 340] running train loss: 0.03905814620940124, running train accuracy: 0.7485294342041016
# [Batch: 360] running train loss: 0.03905711326127251, running train accuracy: 0.7485243082046509
# [Batch: 380] running train loss: 0.039001203583259335, running train accuracy: 0.7497532963752747
# [Batch: 400] running train loss: 0.03890338172670454, running train accuracy: 0.7503905892372131
# [Batch: 420] running train loss: 0.038875184381114584, running train accuracy: 0.750186026096344
# [Batch: 440] running train loss: 0.038851119175722655, running train accuracy: 0.750781238079071
# [Batch: 460] running train loss: 0.03890845034190494, running train accuracy: 0.7504075765609741
# [Batch: 480] running train loss: 0.03890730869413043, running train accuracy: 0.7506185173988342
# [Batch: 500] running train loss: 0.038910680811852214, running train accuracy: 0.7499687671661377
# [Batch: 520] running train loss: 0.038934061604623614, running train accuracy: 0.7499399185180664
# [Batch: 540] running train loss: 0.03887978114394678, running train accuracy: 0.7501735687255859
# [Batch: 560] running train loss: 0.03879742818285844, running train accuracy: 0.7506975531578064
# [Batch: 580] running train loss: 0.03879823721945286, running train accuracy: 0.7506465315818787
# [Batch: 600] running train loss: 0.03878570154309273, running train accuracy: 0.7508072853088379
# [Batch: 620] running train loss: 0.038720567518424606, running train accuracy: 0.7520161271095276
# [Batch: 640] running train loss: 0.038661476038396356, running train accuracy: 0.752758800983429
# [Batch: 660] running train loss: 0.03864338492523089, running train accuracy: 0.7530776262283325
# [Batch: 680] running train loss: 0.03854243221199688, running train accuracy: 0.7539981603622437
# [Batch: 700] running train loss: 0.038505828149084535, running train accuracy: 0.7544196248054504
# train loss: 0.03851382835351358, accuracy: 0.7544701099395752
# elapsed time: 1268.8011660575867
# [Epoch: 8 - Validation]
# [Batch: 1] running val loss: 0.054745834320783615, running val accuracy: 0.640625
# [Batch: 20] running val loss: 0.05802263971418142, running val accuracy: 0.62109375
# [Batch: 40] running val loss: 0.058156485483050344, running val accuracy: 0.615234375
# [Batch: 60] running val loss: 0.058186228138705096, running val accuracy: 0.6104167103767395
# [Batch: 80] running val loss: 0.05804948015138507, running val accuracy: 0.609570324420929
# [Batch: 100] running val loss: 0.058262244313955304, running val accuracy: 0.6095312237739563
# [Batch: 120] running val loss: 0.05852591786533594, running val accuracy: 0.6058593988418579
# [Batch: 140] running val loss: 0.058801110381526606, running val accuracy: 0.6039062738418579
# val loss: 0.05891360635757446, accuracy: 0.6029999852180481
# elapsed time: 124.51746964454651
# [Info] best validation accuracy!
# [Epoch: 9 - Training]
# [Batch: 20] running train loss: 0.03778343815356493, running train accuracy: 0.7601562738418579
# [Batch: 40] running train loss: 0.03759380569681525, running train accuracy: 0.764453113079071
# [Batch: 60] running train loss: 0.03673201759035389, running train accuracy: 0.7690104842185974
# [Batch: 80] running train loss: 0.03678352946881205, running train accuracy: 0.7685546875
# [Batch: 100] running train loss: 0.036902535054832694, running train accuracy: 0.7678124904632568
# [Batch: 120] running train loss: 0.03683954767572383, running train accuracy: 0.7662760615348816
# [Batch: 140] running train loss: 0.036608757531004295, running train accuracy: 0.7680803537368774
# [Batch: 160] running train loss: 0.03650338550796732, running train accuracy: 0.77099609375
# [Batch: 180] running train loss: 0.036747262399229735, running train accuracy: 0.7681424021720886
# [Batch: 200] running train loss: 0.03655808104202151, running train accuracy: 0.7697656154632568
# [Batch: 220] running train loss: 0.03638554879210212, running train accuracy: 0.7723721265792847
# [Batch: 240] running train loss: 0.0364633747531722, running train accuracy: 0.7716146111488342
# [Batch: 260] running train loss: 0.03644445380912377, running train accuracy: 0.7713341116905212
# [Batch: 280] running train loss: 0.036381768860987256, running train accuracy: 0.7719866037368774
# [Batch: 300] running train loss: 0.03627944222961863, running train accuracy: 0.7739583253860474
# [Batch: 320] running train loss: 0.036222740332596, running train accuracy: 0.774462878704071
# [Batch: 340] running train loss: 0.03629004004247048, running train accuracy: 0.7731158137321472
# [Batch: 360] running train loss: 0.036345113938053446, running train accuracy: 0.7729600667953491
# [Batch: 380] running train loss: 0.036280790294863675, running train accuracy: 0.7738075852394104
# [Batch: 400] running train loss: 0.0361903267307207, running train accuracy: 0.7742968797683716
# [Batch: 420] running train loss: 0.03611752481776334, running train accuracy: 0.7748140096664429
# [Batch: 440] running train loss: 0.03607006552205844, running train accuracy: 0.7746448516845703
# [Batch: 460] running train loss: 0.036037735244178255, running train accuracy: 0.7748640775680542
# [Batch: 480] running train loss: 0.03598803534793357, running train accuracy: 0.7749024033546448
# [Batch: 500] running train loss: 0.03599241395294666, running train accuracy: 0.7747812867164612
# [Batch: 520] running train loss: 0.036015311427987536, running train accuracy: 0.774489164352417
# [Batch: 540] running train loss: 0.03591170501722782, running train accuracy: 0.7748842239379883
# [Batch: 560] running train loss: 0.035894596709736756, running train accuracy: 0.7750837206840515
# [Batch: 580] running train loss: 0.035875023914308385, running train accuracy: 0.7751885652542114
# [Batch: 600] running train loss: 0.03583407437739273, running train accuracy: 0.7754427194595337
# [Batch: 620] running train loss: 0.03578625218942762, running train accuracy: 0.7757308483123779
# [Batch: 640] running train loss: 0.03578149652457796, running train accuracy: 0.7757812738418579
# [Batch: 660] running train loss: 0.03574345970921444, running train accuracy: 0.7761600017547607
# [Batch: 680] running train loss: 0.035709828141090624, running train accuracy: 0.7763786911964417
# [Batch: 700] running train loss: 0.035695730253521886, running train accuracy: 0.7766517996788025
# train loss: 0.035705156705709784, accuracy: 0.7767200469970703
# elapsed time: 1269.6118803024292
# [Epoch: 9 - Validation]
# [Batch: 1] running val loss: 0.059963103383779526, running val accuracy: 0.59375
# [Batch: 20] running val loss: 0.06395402625203132, running val accuracy: 0.592968761920929
# [Batch: 40] running val loss: 0.06382768480107189, running val accuracy: 0.592968761920929
# [Batch: 60] running val loss: 0.06454591465493044, running val accuracy: 0.5856770873069763
# [Batch: 80] running val loss: 0.06503524505533279, running val accuracy: 0.582812488079071
# [Batch: 100] running val loss: 0.0651078348979354, running val accuracy: 0.5801562666893005
# [Batch: 120] running val loss: 0.06559432977810502, running val accuracy: 0.5781250596046448
# [Batch: 140] running val loss: 0.06579833887517453, running val accuracy: 0.5761160850524902
# val loss: 0.065992573428154, accuracy: 0.5759999752044678
# elapsed time: 124.34657454490662
# [Epoch: 10 - Training]
# [Batch: 20] running train loss: 0.03342949906364083, running train accuracy: 0.7875000238418579
# [Batch: 40] running train loss: 0.03433724087662995, running train accuracy: 0.7855468988418579
# [Batch: 60] running train loss: 0.034179929985354345, running train accuracy: 0.7864583730697632
# [Batch: 80] running train loss: 0.034274804103188214, running train accuracy: 0.7876953482627869
# [Batch: 100] running train loss: 0.034096570443362, running train accuracy: 0.7907812595367432
# [Batch: 120] running train loss: 0.033957343610624476, running train accuracy: 0.7908854484558105
# [Batch: 140] running train loss: 0.03416437356333647, running train accuracy: 0.7885044813156128
# [Batch: 160] running train loss: 0.03418065127916634, running train accuracy: 0.7886719107627869
# [Batch: 180] running train loss: 0.033914872517602314, running train accuracy: 0.7908854484558105
# [Batch: 200] running train loss: 0.033912082398310305, running train accuracy: 0.7914843559265137
# [Batch: 220] running train loss: 0.03411539995365522, running train accuracy: 0.7897726893424988

# %%
plt.plot([x[0] for x in history], 'b', label='train')
plt.plot([x[1] for x in history], 'r--',label='validation')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4ef12f1513a6> in <cell line: 1>()
# ----> 1 plt.plot([x[0] for x in history], 'b', label='train')
#       2 plt.plot([x[1] for x in history], 'r--',label='validation')
#       3 plt.xlabel("Epochs")
#       4 plt.ylabel("Loss")
#       5 plt.legend()
#
# NameError: name 'plt' is not defined

# %%
plt.plot([x[0] for x in accuracy], 'b', label='train')
plt.plot([x[1] for x in accuracy], 'r--',label='validation')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %% [markdown]
# #### <b>Final Test</b>

# %%
saved_path = "/content/gdrive/MyDrive/Colab Notebooks/AI1"  # 모델 저장할 경로
best_epoch = 7
net.load_state_dict(torch.load(f'{saved_path}/best_checkpoint_epoch_' + str(best_epoch + 1) + '.pth'))

def test():
    start_time = time.time()
    net.eval()
    total = 0
    running_loss = 0.0
    running_corrects = 0

    for i, batch in enumerate(test_dataloader):
        img1, img2, label, weight = batch
        img1, img2, label, weight = img1.cuda(), img2.cuda(), label.float().view(-1, 1).cuda(), weight.float().view(-1, 1).cuda()

        with torch.no_grad():
            output = net(img1, img2)
            preds = sigmoid(output) >= 0.5
            loss = criterion(output, label)
            loss = loss * weight
            loss = torch.mean(loss)

        total += label.shape[0]
        running_loss += loss.item()
        running_corrects += torch.sum(preds == (label >= 0.5))

        if (i == 0) or (i % log_step == log_step - 1):
            print(f'[Batch: {i + 1}] running test loss: {running_loss / total}, running test accuracy: {running_corrects / total}')

    print(f'test loss: {running_loss / total}, accuracy: {running_corrects / total}')
    print("elapsed time:", time.time() - start_time)
    return running_loss / total, (running_corrects / total).item()

test()
# Out:
# [Batch: 1] running test loss: 0.04845619201660156, running test accuracy: 0.703125
# [Batch: 20] running test loss: 0.05810017604380846, running test accuracy: 0.614062488079071
# [Batch: 40] running test loss: 0.05859205834567547, running test accuracy: 0.6117187738418579
# [Batch: 60] running test loss: 0.05896817687898874, running test accuracy: 0.6075521111488342
# [Batch: 80] running test loss: 0.059435845958068965, running test accuracy: 0.607617199420929
# [Batch: 100] running test loss: 0.05959237080067396, running test accuracy: 0.6087499856948853
# [Batch: 120] running test loss: 0.058908607624471185, running test accuracy: 0.6132813096046448
# [Batch: 140] running test loss: 0.058898171250309266, running test accuracy: 0.61328125
# test loss: 0.05910905675888062, accuracy: 0.6151999831199646
# elapsed time: 125.47223091125488
# (0.05910905675888062, 0.6151999831199646)

# %% [markdown]
# #### <b>Using Ensembles</b>

# %%
# checkpoints = [15, 16, 17, 18, 19]
checkpoints = [1]

models = []
for checkpoint in checkpoints:
    model = SiameseNet().cuda()
    model = nn.DataParallel(model)
    state_dict = torch.load(f"{saved_path}/checkpoint_epoch_{checkpoint}.pth")
    model.load_state_dict(state_dict)
    
    models.append(model)

# %%
def test_ensembles():
    start_time = time.time()
    total = 0
    running_loss = 0.0
    running_corrects = 0

    for i, batch in enumerate(test_dataloader):
        img1, img2, label, weight = batch
        img1, img2, label, weight = img1.cuda(), img2.cuda(), label.float().view(-1, 1).cuda(), weight.float().view(-1, 1).cuda()

        preds = 0
        losses = 0
        for model in models:
            model.eval()
            with torch.no_grad():
                output = model(img1, img2)
                preds += sigmoid(output) / len(models)
                loss = criterion(output, label)
                loss = loss * weight
                loss = torch.mean(loss)
                losses += loss / len(models)

        pred = preds >= 0.5
        total += label.shape[0]
        running_loss += losses.item()
        running_corrects += torch.sum(pred == (label >= 0.5))

        if (i == 0) or (i % log_step == log_step - 1):
            print(f'[Batch: {i + 1}] running test loss: {running_loss / total}, running test accuracy: {running_corrects / total}')

    print(f'test loss: {running_loss / total}, accuracy: {running_corrects / total}')
    print("elapsed time:", time.time() - start_time)
    return running_loss / total, (running_corrects / total).item()

test_ensembles()
# Out:
# [Batch: 1] running test loss: 0.05640115588903427, running test accuracy: 0.59375
# [Batch: 20] running test loss: 0.057562794908881186, running test accuracy: 0.54296875
# [Batch: 40] running test loss: 0.057389537803828716, running test accuracy: 0.548828125
# [Batch: 60] running test loss: 0.05750474644203981, running test accuracy: 0.5458333492279053
# [Batch: 80] running test loss: 0.05764713655225932, running test accuracy: 0.5482422113418579
# [Batch: 100] running test loss: 0.057710480876266956, running test accuracy: 0.5412499904632568
# [Batch: 120] running test loss: 0.05778773929923773, running test accuracy: 0.5393229722976685
# [Batch: 140] running test loss: 0.057668855333966866, running test accuracy: 0.5430803894996643
# test loss: 0.058048321175575256, accuracy: 0.5411999821662903
# elapsed time: 125.55152773857117
# (0.058048321175575256, 0.5411999821662903)

# %% [markdown]
# #### <b>Custom Test</b>

# %%
# !git clone https://github.com/ndb796/korean_face_age_classification
# Out:
# Cloning into 'korean_face_age_classification'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 85 (delta 30), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (85/85), 4.22 MiB | 7.32 MiB/s, done.

# %%
# %%capture
# !wget https://postechackr-my.sharepoint.com/:u:/g/personal/dongbinna_postech_ac_kr/ERO90Zk8tGlGn4nM1VM6UpkBuJV5rdKmYU4ia7wRp-K4CA?download=1 -O saved_best_checkpoint_epoch.pth

# %%
net = SiameseNet().cuda()
net = nn.DataParallel(net)
state_dict = torch.load(f"./saved_best_checkpoint_epoch.pth")
net.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
test()
# Out:
# [Batch: 1] running test loss: 0.0650169849395752, running test accuracy: 0.59375
# [Batch: 20] running test loss: 0.06466656439006328, running test accuracy: 0.578125
# [Batch: 40] running test loss: 0.06305804178118705, running test accuracy: 0.6019531488418579
# [Batch: 60] running test loss: 0.06337643197427194, running test accuracy: 0.6015625596046448
# [Batch: 80] running test loss: 0.0633515341207385, running test accuracy: 0.598437488079071
# [Batch: 100] running test loss: 0.06403283342719078, running test accuracy: 0.5921874642372131
# [Batch: 120] running test loss: 0.0644089635151128, running test accuracy: 0.5919271111488342
# [Batch: 140] running test loss: 0.06413484561656202, running test accuracy: 0.5938616394996643
# test loss: 0.06407643764019012, accuracy: 0.5960999727249146
# elapsed time: 124.7668685913086
# (0.06407643764019012, 0.5960999727249146)

# %%
images = []
image_cnt = 10

for i in range(1, image_cnt + 1):
    filename = f'example_{i}.png'
    image = Image.open('korean_face_age_classification/images/' + filename).convert('RGB')
    image = test_transform(image).unsqueeze(0).cuda()
    images.append(image)

# %%
from itertools import combinations


possibles = list(combinations(images, 2))

for possible in possibles:
    one, two = possible

    with torch.no_grad():
        output = net(one, two)
        pred = sigmoid(output) >= 0.5

    result = pred[0][0].item()
    print(f"가족 관계 예측 결과: {result}")
    # print(f"가족 관계 예측 결과: {result} ({sigmoid(output)[0][0].item()})%")
    out = torchvision.utils.make_grid(torch.stack((one[0], two[0])))
    imshow(out.cpu())
